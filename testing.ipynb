# %%
from model import load_model

model = load_model("best_model.pth")
print("Model loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from model import load_model
#       2
#       3 model = load_model("best_model.pth")
#       4 print("Model loaded successfully")
#
# File ~/Desktop/Deforestation-ML/BE/model.py:11
#       1 """
#       2 model.py — Loads the U-Net deforestation detection model once at startup.
#       3
#    (...)      8   - Trained with BCEWithLogitsLoss on Dynamic World labels
#       9 """
# ---> 11 import torch
#      12 import segmentation_models_pytorch as smp
#      15 def load_model(path: str = "best_model.pth") -> torch.nn.Module:
#
# ModuleNotFoundError: No module named 'torch'
